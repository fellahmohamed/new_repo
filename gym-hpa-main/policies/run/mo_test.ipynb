# %%
# !pip install git+https://github.com/LucasAlegre/morl-baselines.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/LucasAlegre/morl-baselines.git to /tmp/pip-req-build-slq_dbky
#   Running command git clone --filter=blob:none --quiet https://github.com/LucasAlegre/morl-baselines.git /tmp/pip-req-build-slq_dbky
#   Resolved https://github.com/LucasAlegre/morl-baselines.git to commit d3a0ecd6ae766e2e6f4ee6765de7a9898f618947
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pymoo-0.6.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# ...
#   Using cached wandb-0.20.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# ...
#   Using cached moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached cvxpy-1.6.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# ...
#   Using cached fire-0.7.0-py3-none-any.whl
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 12
#      10 from morl_baselines.multi_policy.pgmorl.pgmorl import PGMORL
#      11 from morl_baselines.single_policy.ser.mo_q_learning import MOQLearning
# ---> 12 from morl_baselines.common.utils import seed_everything
#      14 # Gym imports
#      15 import gym
#
# ImportError: cannot import name 'seed_everything' from 'morl_baselines.common.utils' (/home/mohamed/.local/lib/python3.10/site-packages/morl_baselines/common/utils.py)
